# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.set_printoptions(precision = 5,edgeitems = 11, linewidth = 200, suppress = True)
np.core.arrayprint._line_width = 180

# %%
ds = pd.read_excel("https://github.com/Lufec/TopEspCompVIII/raw/master/Lista2_Conjunto1.xlsx", skiprows = 2).drop(columns = 
    ["Unnamed: 0","Unnamed: 1","Unnamed: 8"])
ds.head()
# Out:
#     V1   V2    V3   V4    V5   V6  Classe
# 0  5.1  3.5  4.95  1.4  1.96  0.2       1
# 1  4.9  3.0  5.30  1.4  1.96  0.2       1
# 2  4.7  3.2  4.60  1.3  1.69  0.2       1
# 3  4.6  3.1  4.55  1.5  2.25  0.2       1
# 4  5.0  3.6  4.60  1.4  1.96  0.2       1

# %%
inputs = ds.drop(columns = "Classe")
inputs = np.asarray(inputs)

# %%
col = []
col.append(ds["V1"].to_numpy())
col.append(ds["V2"].to_numpy())
col.append(ds["V3"].to_numpy())
col.append(ds["V4"].to_numpy())
col.append(ds["V5"].to_numpy())
col.append(ds["V6"].to_numpy())
col.append(ds["Classe"].to_numpy())
col = np.asarray(col)

# %%
frequencies = []
for i in range(0,len(col)):
    (unique, counts) = np.unique(col[i], return_counts=True)
    freq = np.asarray((unique, counts)).T
    soma = freq[:,1].sum()
    freq[:,1] = 100*freq[:,1]/soma
    frequencies.append(freq)
#print(frequencies[6])

# %%
maximo = []
minimo = []
escala = []
for i in range(0,len(col)):
    maximo.append(max(col[i]))
    minimo.append(min(col[i]))
    escala.append(max(col[i])-min(col[i]))
#print(escala[0])

# %%
s,p = stats.shapiro(col[0])
print(s)
print(p)
# Out:
# 0.9760899543762207
# 0.010180278681218624

# %%
z = np.abs(stats.zscore(ds))
limite = 3
print(np.where(z>limite))
#ds_out= ds[(z < limite).all(axis=1)]
#ds.info()
#ds_out.info()
###Como tá normalização z, outlier n machuca
# Out:
# (array([15], dtype=int64), array([1], dtype=int64))

# %%
plt.figure(figsize=(15,14))
plt.subplot(421)
sns.distplot(col[0],bins = 4*len(set(col[0])))
plt.subplot(422)
sns.distplot(col[1],bins = 4*len(set(col[1])))
plt.subplot(423)
sns.distplot(col[2],bins = 4*len(set(col[2])))
plt.subplot(424)
sns.distplot(col[3],bins = 4*len(set(col[3])))
plt.subplot(425)
sns.distplot(col[4],bins = 4*len(set(col[4])))
plt.subplot(426)
sns.distplot(col[5],bins = 4*len(set(col[5])))
plt.subplot(427)
sns.distplot(col[6],bins = 4*len(set(col[6])))

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
cor = np.corrcoef(inputs, rowvar = False)
print(cor)
# Out:
# [[ 1.      -0.11757  0.93644  0.87175  0.89752  0.81794]
#  [-0.11757  1.      -0.4585  -0.42844 -0.34149 -0.36613]
#  [ 0.93644 -0.4585   1.       0.9315   0.92383  0.86132]
#  [ 0.87175 -0.42844  0.9315   1.       0.98382  0.96287]
#  [ 0.89752 -0.34149  0.92383  0.98382  1.       0.94592]
#  [ 0.81794 -0.36613  0.86132  0.96287  0.94592  1.     ]]

# %%
col_norm = normalize(col[0:6])
col_norm = np.asarray(col_norm)

# %%
plt.figure(figsize=(15,10))
plt.subplot(321)
sns.distplot(col_norm[0],bins = 4*len(set(col_norm[0])))
plt.subplot(322)
sns.distplot(col_norm[1],bins = 4*len(set(col_norm[1])))
plt.subplot(323)
sns.distplot(col_norm[2],bins = 4*len(set(col_norm[2])))
plt.subplot(324)
sns.distplot(col_norm[3],bins = 4*len(set(col_norm[3])))
plt.subplot(325)
sns.distplot(col_norm[4],bins = 4*len(set(col_norm[4])))
plt.subplot(326)
sns.distplot(col_norm[5],bins = 4*len(set(col_norm[5])))

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
cov = np.cov(col_norm, rowvar = True)
m,v = np.linalg.eig(cov)
print("Autovetores: \n",v)
print("Autovalores: \n",m)
# Out:
# Autovetores:
#  [[-0.13325  0.29536 -0.19575 -0.45552 -0.80572  0.00062]
#  [ 0.05822  0.05048 -0.90692 -0.15358  0.31621  0.21903]
#  [-0.25113  0.44331  0.25769 -0.63587  0.50082 -0.1373 ]
#  [-0.45299  0.06753  0.16606  0.10611 -0.       0.86683]
#  [-0.62844  0.38552 -0.19946  0.519    0.      -0.38377]
#  [-0.56182 -0.74867 -0.07352 -0.28975  0.      -0.18572]]
# Autovalores:
#  [0.00581 0.00015 0.00013 0.00005 0.      0.00001]

# %%
##Descorrelação faço nem ideia ainda
